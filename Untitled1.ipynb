# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevang1-epic/-Jeevang1-epic-Duality-AI-s-Space-Station-Safety-Object-Detection-System-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from  google import genai

# %%
from google.colab import userdata

# %%
client = genai.Client(api_key=userdata.get("gem"))

# %%
def study_assistance(user_prrompt):
  output = client.models.generate_content(
      model = "gemini-2.5-flash",
      contents= user_prrompt
  )
  return output

# %%
output =study_assistance("explain what is generative ai")

# %%
print(output.text)
# Out:
# **Generative AI** refers to a category of artificial intelligence models that are designed to **create new, original content** rather than just analyzing or classifying existing data. Unlike traditional AI, which might recognize a cat in a picture (discriminative AI), generative AI can *draw* a new cat that has never existed before.
#
# Here's a breakdown of what that means:
#
# 1.  **"Generative" means "Creates":** The core function is to generate something from scratch. This "something" can take many forms:
#     *   **Text:** Articles, stories, poems, code, summaries, translations, emails, chatbot responses.
#     *   **Images:** Art, photorealistic scenes, product designs, variations of existing images, character concepts.
#     *   **Audio:** Music, voiceovers, sound effects, synthetic speech.
#     *   **Video:** Short clips, animating still images, generating motion sequences.
#     *   **3D Models:** Objects, environments.
# ...
